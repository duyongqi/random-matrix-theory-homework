# %% [markdown]
# # Random Matrix Theory 实验

# %% [markdown]
# ## Marcenko-Pastur分布和Wigner半圆率

# %%
import numpy as np
import matplotlib.pyplot as plt
pi = np.pi

# %% [markdown]
# ### Marcenko-Pastur Law

# %% [markdown]
# *Gaussian*

# %% [markdown]
# *n=10000, p=50000*

# %%
coeff = 5
p = 1000*coeff
n = 2000*coeff
c = p/n
X = np.array(np.random.randn(p,n))

SCM = X@X.T/n
a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2
edges=np.linspace(a,b,60);

# Limiting measure
mu=np.sqrt( (edges-a)*(b-edges) )/2/pi/c

# Empirical histogram

plt.hist(np.linalg.eig(SCM)[0],bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
plt.plot(edges,mu/edges,'r',label='Marcenko-Pastur law')
plt.legend()

# %% [markdown]
# *n=50000, p=5000*

# %%
coeff = 5
p = 1000*coeff
n = 10000*coeff
c = p/n
X = np.array(np.random.randn(p,n))

SCM = X@X.T/n
a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2
edges=np.linspace(a,b,60);

# Limiting measure
mu=np.sqrt( (edges-a)*(b-edges) )/2/pi/c

# Empirical histogram

plt.hist(np.linalg.eig(SCM)[0],bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
plt.plot(edges,mu/edges,'r',label='Marcenko-Pastur law')
plt.legend()

# %% [markdown]
# *n=5000, p=500*

# %%
coeff = 5
p = 100*coeff
n = 1000*coeff
c = p/n
X = np.array(np.random.randn(p,n))

SCM = X@X.T/n
a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2
edges=np.linspace(a,b,60);

# Limiting measure
mu=np.sqrt( (edges-a)*(b-edges) )/2/pi/c

# Empirical histogram

plt.hist(np.linalg.eig(SCM)[0],bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
plt.plot(edges,mu/edges,'r',label='Marcenko-Pastur law')
plt.legend()

# %% [markdown]
# *n=500, p=50*

# %%
coeff = 5
p = 10*coeff
n = 100*coeff
c = p/n
X = np.array(np.random.randn(p,n))
SCM = X@X.T/n
a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2
edges=np.linspace(a,b,60)

# Limiting measure
mu=np.sqrt( (edges-a)*(b-edges) )/2/pi/c

# Empirical histogram

plt.hist(np.linalg.eig(SCM)[0],bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
plt.plot(edges,mu/edges,'r',label='Marcenko-Pastur law')
# plt.xlim(0, 2)
plt.legend()

# %% [markdown]
# *n=500, p=5000*

# %%
coeff = 5
p = 1000*coeff
n = 100*coeff
c = p/n
X = np.array(np.random.randn(p,n))

SCM = X@X.T/n
a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2
edges=np.linspace(a,b,60)

# Limiting measure
mu=np.sqrt( (edges-a)*(b-edges) )/2/pi/c

# Empirical histogram

plt.hist(np.linalg.eig(SCM)[0],bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
plt.plot(edges,mu/edges,'r',label='Marcenko-Pastur law')
plt.legend()

# %% [markdown]
# *Non Gaussian: stuent-t*

# %% [markdown]
# *n=5000, p=500*

# %%
coeff = 5
p = 100*coeff
n = 1000*coeff
c = p/n
nu_student = 3
X = np.array(np.random.standard_t(nu_student,(p,n)))/np.sqrt(nu_student/(nu_student-2))

# %%
SCM = X@X.T/n
a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2
edges=np.linspace(a,b,60);

# Limiting measure
mu=np.sqrt( (edges-a)*(b-edges) )/2/pi/c

# Empirical histogram
eigs_SCM = np.linalg.eig(SCM)[0]
edge_SCM = np.linspace(np.min(eigs_SCM)-.1,np.max(eigs_SCM)+.2,60)
# plt.hist()
plt.hist(eigs_SCM,bins=edge_SCM,weights=1/p/(edge_SCM[1]-edge_SCM[0])*np.ones(p),label='Empirical eigenvalues')
plt.plot(edges,mu/edges,'r',label='Marcenko-Pastur law')
# plt.xlim(0, 3)
plt.legend()

# %% [markdown]
# ### The Wigner semi-circle law

# %%
coeff = 5
n=20*coeff

Z=np.array(np.random.randn(n,n))
Z_U = np.triu(Z)
X = np.triu(Z) + np.triu(Z,1).T

# %%
edges=np.linspace(-2,2,50)

mu = np.sqrt( np.maximum.reduce( [4 - edges**2, np.zeros(len(edges))] ) )/2/pi

plt.hist(np.linalg.eig(X/np.sqrt(n))[0],bins=edges,weights=1/n/(edges[1]-edges[0])*np.ones(n),label='Empirical eigenvalues')
plt.plot(edges,mu,'r',label='Wigner semi-circle law')
plt.legend()

# %%
coeff = 5
n=200*coeff

Z=np.array(np.random.randn(n,n))
Z_U = np.triu(Z)
X = np.triu(Z) + np.triu(Z,1).T

edges=np.linspace(-2,2,50)

mu = np.sqrt( np.maximum.reduce( [4 - edges**2, np.zeros(len(edges))] ) )/2/pi

plt.hist(np.linalg.eig(X/np.sqrt(n))[0],bins=edges,weights=1/n/(edges[1]-edges[0])*np.ones(n),label='Empirical eigenvalues')
plt.plot(edges,mu,'r',label='Wigner semi-circle law')
plt.legend()

# %%
coeff = 5
n=2000*coeff

Z=np.array(np.random.randn(n,n))
Z_U = np.triu(Z)
X = np.triu(Z) + np.triu(Z,1).T

edges=np.linspace(-2,2,50)

mu = np.sqrt( np.maximum.reduce( [4 - edges**2, np.zeros(len(edges))] ) )/2/pi

plt.hist(np.linalg.eig(X/np.sqrt(n))[0],bins=edges,weights=1/n/(edges[1]-edges[0])*np.ones(n),label='Empirical eigenvalues')
plt.plot(edges,mu,'r',label='Wigner semi-circle law')
plt.legend()

# %% [markdown]
# ### Non Gaussian

# %%
coeff = 5
n=1000*coeff

nu_student = 3
Z = np.array(np.random.standard_t(nu_student,(n,n)))/np.sqrt(nu_student/(nu_student-2))
Z_U = np.triu(Z)
X = np.triu(Z) + np.triu(Z,1).T

# limiting measure
edges=np.linspace(-2,2,50)

mu = np.sqrt( np.maximum.reduce( [4 - edges**2, np.zeros(len(edges))] ) )/2/pi

# empirical histogram
eigs_X = np.linalg.eig(X/np.sqrt(n))[0]
edges_X = np.linspace(np.min(eigs_X)-.1,np.max(eigs_X)+.2,50)
plt.hist(eigs_X,bins=edges_X,weights=1/n/(edges_X[1]-edges_X[0])*np.ones(n),label='Empirical eigenvalues')
plt.plot(edges,mu,'r',label='Wigner semi-circle law')
plt.legend()

# %% [markdown]
# # Spiked model

# %%
import numpy as np
import scipy.linalg
import scipy.sparse.linalg
import scipy.special
import matplotlib.pyplot as plt
pi = np.pi

# %%
coeff = 1
p = 512*coeff
n = p*4
c = p/n

Z = np.array(np.random.randn(p,n))
eig_P = np.array([0.1])

u = np.array(np.random.randn(p,1))
u = u/np.linalg.norm(u)
C = np.eye(p) + eig_P*u@(u.T)
X = scipy.linalg.sqrtm(C) @ Z
SCM = X @ (X.T)/n

eigs_SCM = np.sort(np.linalg.eig(SCM)[0])
edges=np.linspace(np.min(eigs_SCM)-.1,np.max(eigs_SCM)+.1,200)

a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2

isolated_eigs = 1+eig_P+c*(1+eig_P)/eig_P
isolated_eigs[ [ i for i in range(len(eig_P)) if eig_P[i]<=np.sqrt(c) ] ] = np.nan

plt.hist(eigs_SCM, bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
edges_MP=np.linspace(a,b,100)
mu=np.sqrt( (edges_MP-a)*(b-edges_MP) )/2/pi/c
plt.plot(edges_MP,mu/edges_MP,'r',label='Marcenko-Pastur law')
plt.plot(isolated_eigs,np.zeros(len(isolated_eigs)),'rx',label='Isolated eigs per Theorem 2.13')
plt.gca().set_xlim(0,np.max(eigs_SCM)+.5)
plt.gca().set_ylim(0,1)
_ = plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6662: ComplexWarning: Casting complex values to real discards the imaginary part
#   tops = np.array(tops, float)  # causes problems later if it's an int
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:2817: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %%
coeff = 1
p = 512*coeff
n = p*4
c = p/n

Z = np.array(np.random.randn(p,n))
eig_P = np.array([0.3])

u = np.array(np.random.randn(p,1))
u = u/np.linalg.norm(u)
C = np.eye(p) + eig_P*u@(u.T)
X = scipy.linalg.sqrtm(C) @ Z
SCM = X @ (X.T)/n

eigs_SCM = np.sort(np.linalg.eig(SCM)[0])
edges=np.linspace(np.min(eigs_SCM)-.1,np.max(eigs_SCM)+.1,200)

a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2

isolated_eigs = 1+eig_P+c*(1+eig_P)/eig_P
isolated_eigs[ [ i for i in range(len(eig_P)) if eig_P[i]<=np.sqrt(c) ] ] = np.nan

plt.hist(eigs_SCM, bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
edges_MP=np.linspace(a,b,100)
mu=np.sqrt( (edges_MP-a)*(b-edges_MP) )/2/pi/c
plt.plot(edges_MP,mu/edges_MP,'r',label='Marcenko-Pastur law')
plt.plot(isolated_eigs,np.zeros(len(isolated_eigs)),'rx',label='Isolated eigs per Theorem 2.13')
plt.gca().set_xlim(0,np.max(eigs_SCM)+.5)
plt.gca().set_ylim(0,1)
_ = plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6662: ComplexWarning: Casting complex values to real discards the imaginary part
#   tops = np.array(tops, float)  # causes problems later if it's an int
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:2817: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %%
coeff = 1
p = 512*coeff
n = p*4
c = p/n

Z = np.array(np.random.randn(p,n))
eig_P = np.array([0.5])

u = np.array(np.random.randn(p,1))
u = u/np.linalg.norm(u)
C = np.eye(p) + eig_P*u@(u.T)
X = scipy.linalg.sqrtm(C) @ Z
SCM = X @ (X.T)/n

eigs_SCM = np.sort(np.linalg.eig(SCM)[0])
edges=np.linspace(np.min(eigs_SCM)-.1,np.max(eigs_SCM)+.1,200)

a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2

isolated_eigs = 1+eig_P+c*(1+eig_P)/eig_P
isolated_eigs[ [ i for i in range(len(eig_P)) if eig_P[i]<=np.sqrt(c) ] ] = np.nan

plt.hist(eigs_SCM, bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
edges_MP=np.linspace(a,b,100)
mu=np.sqrt( (edges_MP-a)*(b-edges_MP) )/2/pi/c
plt.plot(edges_MP,mu/edges_MP,'r',label='Marcenko-Pastur law')
plt.plot(isolated_eigs,np.zeros(len(isolated_eigs)),'rx',label='Isolated eigs per Theorem 2.13')
plt.gca().set_xlim(0,np.max(eigs_SCM)+.5)
plt.gca().set_ylim(0,1)
_ = plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6662: ComplexWarning: Casting complex values to real discards the imaginary part
#   tops = np.array(tops, float)  # causes problems later if it's an int
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:2817: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %%
coeff = 1
p = 512*coeff
n = p*4
c = p/n

Z = np.array(np.random.randn(p,n))
eig_P = np.array([0.7])

u = np.array(np.random.randn(p,1))
u = u/np.linalg.norm(u)
C = np.eye(p) + eig_P*u@(u.T)
X = scipy.linalg.sqrtm(C) @ Z
SCM = X @ (X.T)/n

eigs_SCM = np.sort(np.linalg.eig(SCM)[0])
edges=np.linspace(np.min(eigs_SCM)-.1,np.max(eigs_SCM)+.1,200)

a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2

isolated_eigs = 1+eig_P+c*(1+eig_P)/eig_P
isolated_eigs[ [ i for i in range(len(eig_P)) if eig_P[i]<=np.sqrt(c) ] ] = np.nan

plt.hist(eigs_SCM, bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
edges_MP=np.linspace(a,b,100)
mu=np.sqrt( (edges_MP-a)*(b-edges_MP) )/2/pi/c
plt.plot(edges_MP,mu/edges_MP,'r',label='Marcenko-Pastur law')
plt.plot(isolated_eigs,np.zeros(len(isolated_eigs)),'rx',label='Isolated eigs per Theorem 2.13')
plt.gca().set_xlim(0,np.max(eigs_SCM)+.5)
plt.gca().set_ylim(0,1)
_ = plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6662: ComplexWarning: Casting complex values to real discards the imaginary part
#   tops = np.array(tops, float)  # causes problems later if it's an int
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:2817: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %%
coeff = 1
p = 512*coeff
n = p*4
c = p/n

Z = np.array(np.random.randn(p,n))
eig_P = np.array([0.9])

u = np.array(np.random.randn(p,1))
u = u/np.linalg.norm(u)
C = np.eye(p) + eig_P*u@(u.T)
X = scipy.linalg.sqrtm(C) @ Z
SCM = X @ (X.T)/n

eigs_SCM = np.sort(np.linalg.eig(SCM)[0])
edges=np.linspace(np.min(eigs_SCM)-.1,np.max(eigs_SCM)+.1,200)

a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2

isolated_eigs = 1+eig_P+c*(1+eig_P)/eig_P
isolated_eigs[ [ i for i in range(len(eig_P)) if eig_P[i]<=np.sqrt(c) ] ] = np.nan

plt.hist(eigs_SCM, bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
edges_MP=np.linspace(a,b,100)
mu=np.sqrt( (edges_MP-a)*(b-edges_MP) )/2/pi/c
plt.plot(edges_MP,mu/edges_MP,'r',label='Marcenko-Pastur law')
plt.plot(isolated_eigs,np.zeros(len(isolated_eigs)),'rx',label='Isolated eigs per Theorem 2.13')
plt.gca().set_xlim(0,np.max(eigs_SCM)+.5)
plt.gca().set_ylim(0,1)
_ = plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6662: ComplexWarning: Casting complex values to real discards the imaginary part
#   tops = np.array(tops, float)  # causes problems later if it's an int
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:2817: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:789: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /usr/local/lib/python3.7/dist-packages/matplotlib/transforms.py:1969: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %%
coeff = 1
p = 512*coeff
n = p*4
c = p/n

Z = np.array(np.random.randn(p,n))
eig_P = np.array([1,2,3,4])
P = np.array(np.diag(np.concatenate([eig_P,np.zeros(p-len(eig_P))])))
C = np.eye(p) + P
X = scipy.linalg.sqrtm(C) @ Z

SCM = X @ (X.T)/n
eigs_SCM = np.sort(np.linalg.eig(SCM)[0])
edges=np.linspace(np.min(eigs_SCM)-.1,np.max(eigs_SCM)+.1,200)

a = (1-np.sqrt(c))**2
b = (1+np.sqrt(c))**2

isolated_eigs = 1+eig_P+c*(1+eig_P)/eig_P
isolated_eigs[ [ i for i in range(len(eig_P)) if eig_P[i]<=np.sqrt(c) ] ] = np.nan

plt.hist(eigs_SCM, bins=edges,weights=1/p/(edges[1]-edges[0])*np.ones(p),label='Empirical eigenvalues')
edges_MP=np.linspace(a,b,100)
mu=np.sqrt( (edges_MP-a)*(b-edges_MP) )/2/pi/c
plt.plot(edges_MP,mu/edges_MP,'r',label='Marcenko-Pastur law')
plt.plot(isolated_eigs,np.zeros(len(isolated_eigs)),'rx',label='Isolated eigs per Theorem 2.13')
plt.gca().set_xlim(0,np.max(eigs_SCM)+.5)
plt.gca().set_ylim(0,1)
_ = plt.legend()

# %%
coeff_loop = [1,4]
popu_spike_loop = np.linspace(.1,4,30)
nb_average_loop = 200
eigvec_alignment = np.zeros( (len(coeff_loop),len(popu_spike_loop),nb_average_loop) )

for i in range(len(coeff_loop)):
    for j in range(len(popu_spike_loop)):
        for average_loop in range(nb_average_loop):
            p = int(128*coeff_loop[i])
            n = p*3
            c = p/n

            eig_P = popu_spike_loop[j]
            Z = np.array(np.random.randn(p,n))

            u = np.array(np.random.randn(p,1))
            u = u/np.linalg.norm(u)
            C = np.eye(p) + eig_P*u@(u.T)
            X = scipy.linalg.sqrtm(C) @ Z

            SCM = X@(X.T)/n
            hat_u = scipy.sparse.linalg.eigs(SCM,1)[1]

            eigvec_alignment[i,j,average_loop] = abs(u.T@hat_u)**2
        
max0 = lambda array : [ max(x,0) for x in array]
theo_alignment = max0((1-c*1/popu_spike_loop**2)/(1+c/popu_spike_loop))

plt.plot(popu_spike_loop,np.mean(eigvec_alignment[0,:,:],axis=1),'b--o',label='$p=128$')
plt.plot(popu_spike_loop,np.mean(eigvec_alignment[1,:,:],axis=1),'b-^',label='$p=512$')
plt.plot(popu_spike_loop,theo_alignment,'r',label=r'$\zeta_1$')
plt.xlabel(r'Population spike $\ell_1$')
plt.ylabel(r'Top eigenvector alignement $| \hat u_1^T u_1 |^2$')
_ = plt.legend()

# %%
def tracy_widom_appx(x, i):

    kappx = [46.44604884387787, 79.6594870666346, 0, 146.0206131050228]   #  K, THETA, ALPHA
    thetaappx = [0.18605402228279347, 0.10103655775856243, 0, 0.05954454047933292]
    alphaappx = [9.848007781128567, 9.819607173436484, 0, 11.00161520109004]

    cdftwappx = cdfgamma(x+alphaappx[i-1], thetaappx[i-1], kappx[i-1])

    pdftwappx = pdfgamma(x+alphaappx[i-1], thetaappx[i-1], kappx[i-1])

    return pdftwappx, cdftwappx

def pdfgamma(x, ta, ka):
    pdf = []
    for x_ in x: 
        if x_ > 0:
            pdf.append(1/(scipy.special.gamma(ka)*ta**ka) * x_**(ka - 1) * np.exp(-x_/ta))
        else:
            pdf.append(0)
    return pdf


def cdfgamma(x, ta, ka):
    cdf = []
    for x_ in x:
        if x_ > 0:
            cdf.append(scipy.special.gammainc(ka,x_/ta))
        else:
            cdf.append(0)
    return cdf

# %%
coeff = 2
p = 128*coeff
n = 256*coeff
c = p/n

nb_loop = 5000
eig_MP_max = []
eig_SCM_max = []

eig_P = np.sqrt(c)/2
sqrt_C= np.array(np.diag(np.sqrt(np.concatenate([ [1+eig_P],np.ones(p-1) ]))))

for loop in range(nb_loop): # empirical evaluation
    Z = np.array(np.random.randn(p,n))
    X = sqrt_C @ Z
    eig_MP_max.append(np.real(scipy.sparse.linalg.eigs(Z@Z.T/n,1)[0][0]))
    eig_SCM_max.append(np.real(scipy.sparse.linalg.eigs(X@X.T/n,1)[0][0]))


# without spikes
edges_MP = np.linspace(np.min(eig_MP_max),np.max(eig_MP_max),60)    
edges = np.linspace(-5,5,100)
factor = c**(-1/6)*(1+np.sqrt(c))**(4/3)

scaled_edges_MP = (edges_MP-(1+np.sqrt(c))**2)*n**(2/3)/factor
    
plt.hist( (eig_MP_max-(1+np.sqrt(c))**2)*n**(2/3)/factor,bins=scaled_edges_MP, weights=1/nb_loop/( scaled_edges_MP[1]-scaled_edges_MP[0] )*np.ones(len(eig_MP_max)) ,label=r'Fluctuation of largest eigvalue')
plt.plot(edges,tracy_widom_appx(edges,1)[0], 'r',label=r'Tracy-Widom law')
plt.title(r'Fluctuation of the largest eigvalue of mull model $\frac{1}{n} Z Z^T$')
_ = plt.legend()


# with spikes
edges_SCM = np.linspace(np.min(eig_SCM_max),np.max(eig_SCM_max),60)    
edges = np.linspace(-5,5,100)
factor = c**(-1/6)*(1+np.sqrt(c))**(4/3)

scaled_edges_SCM = (edges_SCM-(1+np.sqrt(c))**2)*n**(2/3)/factor

plt.figure()
plt.hist( (eig_SCM_max-(1+np.sqrt(c))**2)*n**(2/3)/factor,bins=scaled_edges_SCM, weights=1/nb_loop/( scaled_edges_SCM[1]-scaled_edges_SCM[0] )*np.ones(len(eig_SCM_max)) ,label=r'Fluctuation of largest eigvalue')
plt.plot(edges,tracy_widom_appx(edges,1)[0], 'r',label=r'Tracy-Widom law')
plt.title(r'Fluctuation of the largest eigvalue of $\frac{1}{n} (I+P)^{\frac{1}{2}} Z Z^T (I+P)^{\frac{1}{2}}$')
_ = plt.legend()
